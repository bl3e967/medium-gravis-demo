# %%
import networkx as nx
import numpy as np
import uuid
from matplotlib import cm
import matplotlib.pyplot as plt
import matplotlib as mpl

# %% [markdown]
# # Homogenous Undirected Graph

# %% [markdown]
# ## Test graph generator

# %%
def get_new_test_graph():
    NUM_NODES = 50
    p = 0.5
    seed = 1
    test_graph = nx.dual_barabasi_albert_graph(n=NUM_NODES, p=p, seed=seed, m1=2, m2=1)

    # append node properties
    nx.set_node_attributes(test_graph, dict(test_graph.degree()), name='degree')
    nx.set_node_attributes(test_graph, nx.betweenness_centrality(test_graph), name='betweenness_centrality')

    for node, data in test_graph.nodes(data=True):
        data['node_identifier'] = str(uuid.uuid4())
        data['feature1'] = np.random.random()
        data['feature2'] = np.random.randint(0, high=100)
        data['feature3'] = 1 if np.random.random() > 0.5 else 0

    # append edge properties
    for _, _, data in test_graph.edges(data=True):
        data['feature1'] = np.random.random()
        data['feature2'] = np.random.randint(0, high=100)
    
    return test_graph

test_graph = get_new_test_graph()
nx.draw(test_graph)

# %% [markdown]
# ## Matplotlib Colour Helper

# %%
class MplColorHelper:

    def __init__(self, cmap_name, start_val, stop_val):
        self.cmap_name = cmap_name
        self.cmap = plt.get_cmap(cmap_name)
        self.norm = mpl.colors.Normalize(vmin=start_val, vmax=stop_val)
        self.scalarMap = cm.ScalarMappable(norm=self.norm, cmap=self.cmap)

    def get_rgba(self, val):
        return self.scalarMap.to_rgba(val, bytes=True)

    def get_rgb_str(self, val):
        r, g, b, a = self.get_rgba(val)
        return f"rgb({r},{g},{b})"

# %% [markdown]
# ## Conform node and edge attributes
#
# We set node and edge attributes to values that `gravis` expects to find.
#
# We set `color` for node and edge colouring, and use `click` to add text entries that will be displayed for each node and edge.

# %%
vals = nx.get_node_attributes(test_graph, 'betweenness_centrality').values()
betweenness_min, betweenness_max = min(vals), max(vals)
cm_name = "winter"
node_colors = MplColorHelper(cm_name, betweenness_min, betweenness_max)

vals = nx.get_edge_attributes(test_graph, 'feature1').values()
val_min, val_max = min(vals), max(vals)
edge_colors = MplColorHelper(cm_name, val_min, val_max)

for node, data in test_graph.nodes(data=True):
    data['color'] = node_colors.get_rgb_str(data['betweenness_centrality'])
    data['click'] = (
        f"Node: {data['node_identifier']}"
        "\nNode Features:" +
        f"\nfeature 1: {data['feature1']:.3f}" + 
        f"\nfeature 2: {data['feature2']:.3f}" + 
        f"\nfeature 3: {data['feature3']:.3f}" + 
        f"\nBetweenness Centrality: {data['betweenness_centrality']:.3f}" + 
        f"\nDegree: {data['degree']}"
    )

for u, v, data in test_graph.edges(data=True):
    data['color'] = edge_colors.get_rgb_str(data['feature1'])
    data['click'] = (
        f"Edge: {test_graph.nodes[u]['node_identifier']} -> {test_graph.nodes[v]['node_identifier']}" +
        f"\nEdge Features:" + 
        f"\nfeature 1: {data['feature1']}" + 
        f"\nfeature 2: {data['feature2']}"
    )

# %%
import gravis as gv 

gv.d3(
    test_graph, 

    graph_height=750,
    
    node_size_data_source="betweenness_centrality",
    use_node_size_normalization=True,
    node_size_normalization_min=15,
    node_size_normalization_max=35,
    show_node_label=True,
    node_label_data_source='node_identifier',
    
    edge_size_data_source='feature1',
    use_edge_size_normalization=True,
    edge_size_normalization_min=1,
    edge_size_normalization_max=5,

    many_body_force_strength=-500
)
# Out:
#   <style>
#     /* Main divisions */
#     #iES7O0qmncTKCZdbb-main-div {
#       line-height: normal;
#       box-sizing: content-box;
#       padding: 3px;
#       background-color: white;
#     }
#     #iES7O0qmncTKCZdbb-left-div {
#       float: left;
#       line-height: normal;
#       box-sizing: content-box;
#     }
#     #iES7O0qmncTKCZdbb-right-div {
#       float: left;
#       height: 100%;
#       display: none;
#       line-height: normal;
#       box-sizing: content-box;
#     }
#     #iES7O0qmncTKCZdbb-right-inner-div {
#       padding-left: 5px;
#       padding-right: 2px;
#       overflow-x: hidden;
#       overflow-y: auto;
#       height: 100%;
#       line-height: normal;
#       box-sizing: content-box;
#     }
#
#     /* Graph and details (contained in left-inner-div) */
#     #iES7O0qmncTKCZdbb-graph-div {
#       overflow: hidden;
#       resize: vertical;
#       position: relative;
#       border: 1px solid #ccc;
#       border-radius: 4px;
#       box-shadow: 0px 0px 2px rgba(0, 0, 0, 0.2);
#       display: none;
#       line-height: normal;
#       box-sizing: content-box;
#     }
#     #iES7O0qmncTKCZdbb-details-div {
#       overflow: auto;
#       resize: vertical;
#       margin-top: 5px;
#       border: 1px solid #ccc;
#       border-radius: 4px;
#       box-shadow: 0px 0px 2px rgba(0, 0, 0, 0.2);
#       display: none;
#       line-height: normal;
#       box-sizing: content-box;
#     }
#     #iES7O0qmncTKCZdbb-details-head {
#       user-select: none;
#       padding-left: 4px !important;
#       padding-top: 4px !important;
#       font-size: 8px;
#       font-family: "Lucida Console", Monaco, monospace;
#       color: gray;
#       line-height: normal;
#       box-sizing: content-box;
#     }
#     #iES7O0qmncTKCZdbb-details-body {
#       padding: 10px;
#       padding-top: 6px;
#       font-size: 10px;
#       font-family: "Lucida Console", Monaco, monospace;
#       line-height: normal;
#       box-sizing: content-box;
#     }
#
#     /* Control menu (contained in right-inner-div) */
#     .iES7O0qmncTKCZdbb-menu-item-head {
#       font-size: 11px;
#       font-family: "Lucida Console", Monaco, monospace;
#       color: black;
#       cursor: pointer;
#       padding-left: 5px;
#       padding-right: 0px;
#       padding-top: 5px;
#       padding-bottom: 5px;
#       margin-bottom: 5px;
#       border-radius: 4px;
#       border: 1px solid #ccc;
#       box-shadow: 0px 0px 3px rgba(0, 0, 0, 0.2);
#       line-height: normal;
#       box-sizing: content-box;
#     }
#     .iES7O0qmncTKCZdbb-menu-item-body {
#       margin-left: 5px;
#       margin-bottom: 10px;
#       line-height: normal;
#       box-sizing: content-box;
#     }
#     .iES7O0qmncTKCZdbb-menu-subitem-head {
#       font-size: 9px;
#       font-family: "Lucida Console", Monaco, monospace;
#       font-weight: 600;
#       color: #006429;
#       cursor: default;
#       margin-bottom: 2px;
#       line-height: normal;
#       box-sizing: content-box;
#     }
#     .iES7O0qmncTKCZdbb-menu-subitem-body {
#       font-size: 8px;
#       font-family: "Lucida Console", Monaco, monospace;
#       margin-left: 7px;
#       margin-bottom: 5px;
#       line-height: normal;
#       box-sizing: content-box;
#     }
#     .iES7O0qmncTKCZdbb-labeled-input {
#       all: initial;
#       display: flex;
#       align-items: center;
#       margin-top: 1px;
#       margin-bottom: 1px;
#     }
#     .iES7O0qmncTKCZdbb-label {
#       all: initial;
#       font-size: 8px;
#       font-family: "Lucida Console", Monaco, monospace;
#       font-style: italic;
#       cursor: pointer;
#     }
#     .iES7O0qmncTKCZdbb-slider {
#       width: 100%;
#       margin-bottom: 2px;
#     }
#     .iES7O0qmncTKCZdbb-slider::-moz-focus-outer {
#       border: 0;
#     }
#     .iES7O0qmncTKCZdbb-slider-text-left {
#       font-size: 8px;
#       font-family: "Lucida Console", Monaco, monospace;
#       font-style: italic;
#       color: black;
#       float: left;
#       margin-top: 2px;
#     }
#     .iES7O0qmncTKCZdbb-slider-text-right {
#       font-size: 8px;
#       font-family: "Lucida Console", Monaco, monospace;
#       color: black;
#       float: right;
#     }
#     .iES7O0qmncTKCZdbb-checkbox {
#       margin-left: 0px !important;
#       margin-right: 4px !important;
#       margin-top: 2px !important;
#       margin-bottom: 2px !important;
#       padding: 0px !important;
#     }
#     .iES7O0qmncTKCZdbb-select {
#       cursor: pointer;
#       outline: none;
#       font-size: 8px;
#       font-family: "Lucida Console", Monaco, monospace;
#       color: black;
#       background-color: #f5f5f5;
#       width: 100%;
#       padding-top: 4px !important;
#       padding-bottom: 4px !important;
#       padding-left: 5px;
#       padding-right: 10px;
#       margin-right: 5px;
#       margin-top: 2px;
#       margin-bottom: 2px;
#       border-radius: 4px;
#       border: 1.2px solid #bbb;
#       box-shadow: 0 1px 0 1px rgba(0, 0, 0, 0.04);
#
#       -moz-appearance: none;
#       -webkit-appearance: none;
#       appearance: none;
#       background-image: url('...');
#       background-repeat: no-repeat;
#       background-position: right 4px top 50%;
#       background-size: 6px;
#     }
#     @-moz-document url-prefix() {
#       /* Dirty hack to remove dotted border on focus */
#       .iES7O0qmncTKCZdbb-select {
#         color: transparent !important;
#         text-shadow: 0 0 0 black !important;
#       }
#     }
#     .iES7O0qmncTKCZdbb-select:after {
#       cursor: pointer;
#     }
#     .iES7O0qmncTKCZdbb-button {
#       cursor: pointer;
#       outline: none;
#       font-size: 8px;
#       font-family: "Lucida Console", Monaco, monospace;
#       color: black;
#       background-color: #f2f2f2;
#       padding-top: 4px !important;
#       padding-bottom: 4px !important;
#       padding-left: 10px;
#       padding-right: 10px;
#       margin-top: 2px;
#       margin-bottom: 2px;
#       border-radius: 4px;
#       border: 1.2px solid #bbb;
#       box-shadow: 0 1px 0 1px rgba(0, 0, 0, 0.04);
#     }
#     .iES7O0qmncTKCZdbb-button:hover {
#       border: 1.2px solid #999;
#       background-color: #f2f2f2;
#     }
#     .iES7O0qmncTKCZdbb-button:active {
#       background-color: #ddd;
#     }
#     .iES7O0qmncTKCZdbb-button::-moz-focus-inner {
#       border: 0;
#     }
#     /* Hidden menu items */
#     #iES7O0qmncTKCZdbb-graph-select-div {
#       display: none;
#     }
#     #iES7O0qmncTKCZdbb-node-size-norm-div {
#       display: none;
#     }
#     #iES7O0qmncTKCZdbb-edge-size-norm-div {
#       display: none;
#     }
#
#     /* Graph */
#     #iES7O0qmncTKCZdbb-tooltip-div {
#       font-size: 10px;
#       font-family: "Lucida Console", Monaco, monospace;
#       z-index: 42001;
#       opacity: 0;
#       visibility: hidden;
#       position: absolute !important;
#       max-width: 40%;
#       padding: 5px;
#       white-space: pre-wrap;
#       word-break: break-word;
#       color: black;
#       background-color: white;
#       border-radius: 4px;
#       border: 1px solid #ccc;
#       box-shadow: 0px 0px 4px rgba(0, 0, 0, 0.2);
#       line-height: normal;
#       box-sizing: content-box;
#     }
#     #iES7O0qmncTKCZdbb-menu-toggle-button, #iES7O0qmncTKCZdbb-details-toggle-button, #iES7O0qmncTKCZdbb-progress-container {
#       font-size: 14px;
#       font-family: "Lucida Console", Monaco, monospace;
#       z-index: 42000;
#       cursor: pointer;
#       position: absolute;
#       background-color: white;
#       border-radius: 4px;
#       box-shadow: 0px 0px 4px rgba(0, 0, 0, 0.2);
#       line-height: normal;
#       box-sizing: content-box;
#     }
#     #iES7O0qmncTKCZdbb-menu-toggle-button {
#       top: 0;
#       right: 0;
#       padding-left: 6px;
#       padding-right: 6px;
#       padding-top: 12px;
#       padding-bottom: 12px;
#       border-top: 0px;
#       border-right: 0px;
#       border-bottom: 1px solid #ccc;
#       border-left: 1px solid #ccc;
#     }
#     #iES7O0qmncTKCZdbb-details-toggle-button {
#       bottom: 0;
#       left: 0;
#       padding-left: 19px;
#       padding-right: 19px;
#       padding-top: 0.5px;
#       padding-bottom: 2px;
#       border-top: 1px solid #ccc;
#       border-right: 1px solid #ccc;
#       border-bottom: 0px;
#       border-left: 0px;
#     }
#     #iES7O0qmncTKCZdbb-progress-container {
#       font-size: 10px;
#       text-align: center;
#       top: 46%;
#       left: 15%;
#       width: 70%;
#       padding: 8px;
#       border: none

# %% [markdown]
# # Homogenous Directed Graph

# %% [markdown]
# ## Test graph generator

# %%
def get_new_test_digraph():
    NUM_NODES = 50
    test_graph = nx.scale_free_graph(n=NUM_NODES, seed=0, alpha=0.5, beta=0.2, gamma=0.3)

    # append node properties
    nx.set_node_attributes(test_graph, dict(test_graph.degree()), name='degree')
    nx.set_node_attributes(test_graph, nx.betweenness_centrality(test_graph), name='betweenness_centrality')

    for node, data in test_graph.nodes(data=True):
            
        data['node_type'] = 0 if node < 25 else 1

        data['node_identifier'] = str(uuid.uuid4())
        data['feature1'] = np.random.random()
        data['feature2'] = np.random.randint(0, high=100)
        data['feature3'] = 1 if np.random.random() > 0.5 else 0

    # append edge properties
    for u, v, data in test_graph.edges(data=True):
        data['feature1'] = np.random.random()
        data['feature2'] = np.random.randint(0, high=100)
        
    return test_graph

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10,10))
test_graph = get_new_test_digraph()
nx.draw_networkx(test_graph, node_size=150)

# %% [markdown]
# ## Conform node and edge attributes
#
# We do the same for node and edge attributes and conform them to values expected by `gravis`.
#
# The only difference this time is now we have to differentiate between the two node types we have in our heterogeneous graph.
#
# We use the `shape` attribute to set circles for `node_type = 0` and triangles for `node_type = 1`.

# %%
# prep node color generator
vals = nx.get_node_attributes(test_graph, 'betweenness_centrality').values()
betweenness_min, betweenness_max = min(vals), max(vals)
cm_name = "winter"
node_colors = MplColorHelper(cm_name, betweenness_min, betweenness_max)

for node, data in test_graph.nodes(data=True):
    data['value'] = data['betweenness_centrality'] # node size
    data['label'] = data['node_identifier'] 
    data['title'] = (
        f"Node: {data['node_identifier']}"
        "\nNode Features:" +
        f"\nfeature 1: {data['feature1']}" + 
        f"\nfeature 2: {data['feature2']}" + 
        f"\nfeature 3: {data['feature3']}" + 
        f"\nBetweenness Centrality: {data['betweenness_centrality']}" + 
        f"\nDegree: {data['degree']}"
    ) 
    data['color'] = node_colors.get_rgb_str(data['betweenness_centrality'])
    data['shape'] = 'dot' if data['node_type'] == 0 else 'triangle'
    
for u, v, data in test_graph.edges(data=True):
    # data['value'] = data['feature1']
    data['color'] = edge_colors.get_rgb_str(data['feature1'])
    data['title'] = (
        f"Edge: {test_graph.nodes[u]['node_identifier']} -> {test_graph.nodes[v]['node_identifier']}" +
        f"\nEdge Features:" + 
        f"\nfeature 1: {data['feature1']}" + 
        f"\nfeature 2: {data['feature2']}"
    )

# %% [markdown]
# Finally, we set the `edge_curvature` parameter so that we prevent edges from overlapping when there are many of them between two nodes.

# %%
import gravis as gv 

gv.d3(
    test_graph, 

    graph_height=700,
    
    node_size_data_source="betweenness_centrality",
    use_node_size_normalization=True,
    node_size_normalization_min=15,
    node_size_normalization_max=35,
    show_node_label=False,
    node_label_data_source='node_identifier',
    
    edge_size_data_source='feature1',
    use_edge_size_normalization=True,
    edge_size_normalization_min=1,
    edge_size_normalization_max=5,
    edge_curvature=-0.5,

    many_body_force_strength=-500
)
# Out:
#   <style>
#     /* Main divisions */
#     #iWWwQF3s9vpE5rm6Z-main-div {
#       line-height: normal;
#       box-sizing: content-box;
#       padding: 3px;
#       background-color: white;
#     }
#     #iWWwQF3s9vpE5rm6Z-left-div {
#       float: left;
#       line-height: normal;
#       box-sizing: content-box;
#     }
#     #iWWwQF3s9vpE5rm6Z-right-div {
#       float: left;
#       height: 100%;
#       display: none;
#       line-height: normal;
#       box-sizing: content-box;
#     }
#     #iWWwQF3s9vpE5rm6Z-right-inner-div {
#       padding-left: 5px;
#       padding-right: 2px;
#       overflow-x: hidden;
#       overflow-y: auto;
#       height: 100%;
#       line-height: normal;
#       box-sizing: content-box;
#     }
#
#     /* Graph and details (contained in left-inner-div) */
#     #iWWwQF3s9vpE5rm6Z-graph-div {
#       overflow: hidden;
#       resize: vertical;
#       position: relative;
#       border: 1px solid #ccc;
#       border-radius: 4px;
#       box-shadow: 0px 0px 2px rgba(0, 0, 0, 0.2);
#       display: none;
#       line-height: normal;
#       box-sizing: content-box;
#     }
#     #iWWwQF3s9vpE5rm6Z-details-div {
#       overflow: auto;
#       resize: vertical;
#       margin-top: 5px;
#       border: 1px solid #ccc;
#       border-radius: 4px;
#       box-shadow: 0px 0px 2px rgba(0, 0, 0, 0.2);
#       display: none;
#       line-height: normal;
#       box-sizing: content-box;
#     }
#     #iWWwQF3s9vpE5rm6Z-details-head {
#       user-select: none;
#       padding-left: 4px !important;
#       padding-top: 4px !important;
#       font-size: 8px;
#       font-family: "Lucida Console", Monaco, monospace;
#       color: gray;
#       line-height: normal;
#       box-sizing: content-box;
#     }
#     #iWWwQF3s9vpE5rm6Z-details-body {
#       padding: 10px;
#       padding-top: 6px;
#       font-size: 10px;
#       font-family: "Lucida Console", Monaco, monospace;
#       line-height: normal;
#       box-sizing: content-box;
#     }
#
#     /* Control menu (contained in right-inner-div) */
#     .iWWwQF3s9vpE5rm6Z-menu-item-head {
#       font-size: 11px;
#       font-family: "Lucida Console", Monaco, monospace;
#       color: black;
#       cursor: pointer;
#       padding-left: 5px;
#       padding-right: 0px;
#       padding-top: 5px;
#       padding-bottom: 5px;
#       margin-bottom: 5px;
#       border-radius: 4px;
#       border: 1px solid #ccc;
#       box-shadow: 0px 0px 3px rgba(0, 0, 0, 0.2);
#       line-height: normal;
#       box-sizing: content-box;
#     }
#     .iWWwQF3s9vpE5rm6Z-menu-item-body {
#       margin-left: 5px;
#       margin-bottom: 10px;
#       line-height: normal;
#       box-sizing: content-box;
#     }
#     .iWWwQF3s9vpE5rm6Z-menu-subitem-head {
#       font-size: 9px;
#       font-family: "Lucida Console", Monaco, monospace;
#       font-weight: 600;
#       color: #006429;
#       cursor: default;
#       margin-bottom: 2px;
#       line-height: normal;
#       box-sizing: content-box;
#     }
#     .iWWwQF3s9vpE5rm6Z-menu-subitem-body {
#       font-size: 8px;
#       font-family: "Lucida Console", Monaco, monospace;
#       margin-left: 7px;
#       margin-bottom: 5px;
#       line-height: normal;
#       box-sizing: content-box;
#     }
#     .iWWwQF3s9vpE5rm6Z-labeled-input {
#       all: initial;
#       display: flex;
#       align-items: center;
#       margin-top: 1px;
#       margin-bottom: 1px;
#     }
#     .iWWwQF3s9vpE5rm6Z-label {
#       all: initial;
#       font-size: 8px;
#       font-family: "Lucida Console", Monaco, monospace;
#       font-style: italic;
#       cursor: pointer;
#     }
#     .iWWwQF3s9vpE5rm6Z-slider {
#       width: 100%;
#       margin-bottom: 2px;
#     }
#     .iWWwQF3s9vpE5rm6Z-slider::-moz-focus-outer {
#       border: 0;
#     }
#     .iWWwQF3s9vpE5rm6Z-slider-text-left {
#       font-size: 8px;
#       font-family: "Lucida Console", Monaco, monospace;
#       font-style: italic;
#       color: black;
#       float: left;
#       margin-top: 2px;
#     }
#     .iWWwQF3s9vpE5rm6Z-slider-text-right {
#       font-size: 8px;
#       font-family: "Lucida Console", Monaco, monospace;
#       color: black;
#       float: right;
#     }
#     .iWWwQF3s9vpE5rm6Z-checkbox {
#       margin-left: 0px !important;
#       margin-right: 4px !important;
#       margin-top: 2px !important;
#       margin-bottom: 2px !important;
#       padding: 0px !important;
#     }
#     .iWWwQF3s9vpE5rm6Z-select {
#       cursor: pointer;
#       outline: none;
#       font-size: 8px;
#       font-family: "Lucida Console", Monaco, monospace;
#       color: black;
#       background-color: #f5f5f5;
#       width: 100%;
#       padding-top: 4px !important;
#       padding-bottom: 4px !important;
#       padding-left: 5px;
#       padding-right: 10px;
#       margin-right: 5px;
#       margin-top: 2px;
#       margin-bottom: 2px;
#       border-radius: 4px;
#       border: 1.2px solid #bbb;
#       box-shadow: 0 1px 0 1px rgba(0, 0, 0, 0.04);
#
#       -moz-appearance: none;
#       -webkit-appearance: none;
#       appearance: none;
#       background-image: url('...');
#       background-repeat: no-repeat;
#       background-position: right 4px top 50%;
#       background-size: 6px;
#     }
#     @-moz-document url-prefix() {
#       /* Dirty hack to remove dotted border on focus */
#       .iWWwQF3s9vpE5rm6Z-select {
#         color: transparent !important;
#         text-shadow: 0 0 0 black !important;
#       }
#     }
#     .iWWwQF3s9vpE5rm6Z-select:after {
#       cursor: pointer;
#     }
#     .iWWwQF3s9vpE5rm6Z-button {
#       cursor: pointer;
#       outline: none;
#       font-size: 8px;
#       font-family: "Lucida Console", Monaco, monospace;
#       color: black;
#       background-color: #f2f2f2;
#       padding-top: 4px !important;
#       padding-bottom: 4px !important;
#       padding-left: 10px;
#       padding-right: 10px;
#       margin-top: 2px;
#       margin-bottom: 2px;
#       border-radius: 4px;
#       border: 1.2px solid #bbb;
#       box-shadow: 0 1px 0 1px rgba(0, 0, 0, 0.04);
#     }
#     .iWWwQF3s9vpE5rm6Z-button:hover {
#       border: 1.2px solid #999;
#       background-color: #f2f2f2;
#     }
#     .iWWwQF3s9vpE5rm6Z-button:active {
#       background-color: #ddd;
#     }
#     .iWWwQF3s9vpE5rm6Z-button::-moz-focus-inner {
#       border: 0;
#     }
#     /* Hidden menu items */
#     #iWWwQF3s9vpE5rm6Z-graph-select-div {
#       display: none;
#     }
#     #iWWwQF3s9vpE5rm6Z-node-size-norm-div {
#       display: none;
#     }
#     #iWWwQF3s9vpE5rm6Z-edge-size-norm-div {
#       display: none;
#     }
#
#     /* Graph */
#     #iWWwQF3s9vpE5rm6Z-tooltip-div {
#       font-size: 10px;
#       font-family: "Lucida Console", Monaco, monospace;
#       z-index: 42001;
#       opacity: 0;
#       visibility: hidden;
#       position: absolute !important;
#       max-width: 40%;
#       padding: 5px;
#       white-space: pre-wrap;
#       word-break: break-word;
#       color: black;
#       background-color: white;
#       border-radius: 4px;
#       border: 1px solid #ccc;
#       box-shadow: 0px 0px 4px rgba(0, 0, 0, 0.2);
#       line-height: normal;
#       box-sizing: content-box;
#     }
#     #iWWwQF3s9vpE5rm6Z-menu-toggle-button, #iWWwQF3s9vpE5rm6Z-details-toggle-button, #iWWwQF3s9vpE5rm6Z-progress-container {
#       font-size: 14px;
#       font-family: "Lucida Console", Monaco, monospace;
#       z-index: 42000;
#       cursor: pointer;
#       position: absolute;
#       background-color: white;
#       border-radius: 4px;
#       box-shadow: 0px 0px 4px rgba(0, 0, 0, 0.2);
#       line-height: normal;
#       box-sizing: content-box;
#     }
#     #iWWwQF3s9vpE5rm6Z-menu-toggle-button {
#       top: 0;
#       right: 0;
#       padding-left: 6px;
#       padding-right: 6px;
#       padding-top: 12px;
#       padding-bottom: 12px;
#       border-top: 0px;
#       border-right: 0px;
#       border-bottom: 1px solid #ccc;
#       border-left: 1px solid #ccc;
#     }
#     #iWWwQF3s9vpE5rm6Z-details-toggle-button {
#       bottom: 0;
#       left: 0;
#       padding-left: 19px;
#       padding-right: 19px;
#       padding-top: 0.5px;
#       padding-bottom: 2px;
#       border-top: 1px solid #ccc;
#       border-right: 1px solid #ccc;
#       border-bottom: 0px;
#       border-left: 0px;
#     }
#     #iWWwQF3s9vpE5rm6Z-progress-container {
#       font-size: 10px;
#       text-align: center;
#       top: 46%;
#       left: 15%;
#       width: 70%;
#       padding: 8px;
#       border: none
